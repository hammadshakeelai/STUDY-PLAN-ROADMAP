# %% [markdown]
#  #####  link  Adding  Format   **[**    title    **](**    https  full link     **)**

# %% [markdown]
# [Slagle’s 26 problems](https://sites.google.com/site/slaglesmathnasium/previous-years/2018-2019/engineering)

# %% [markdown]
# [![image.png](attachment:image.png)](https://dspace.mit.edu/bitstream/handle/1721.1/11997/31225400-MIT.pdf?sequence=2&isAllowed=y)

# %% [markdown]
# [ARTIFICIAL INTELLIGENCE Third Edition Patrick Henry Winston](https://courses.csail.mit.edu/6.034f/ai3/rest.pdf)

# %% [markdown]
# [James Slagle's SAINT program (Symbolic Automatic Integrator)](https://stacks.stanford.edu/file/druid:fb373ch9229/fb373ch9229.pdf)

# %% [markdown]
# # LETTER FORMAT

# %% [raw]
# To
# Position of set person
# Name
# Organization of affiliation
# Place
#
# Subject:
#
# Warm opening + reson
#
# Details
#
# Context
#
# Employ to mercy
#
# Warm ending
#
# +docs mention
#
# Thank
#
# Yours
# Name
# Extroducton
# organization
